# %%
import glob
import os
import librosa
import torchaudio
import torch
import matplotlib.pyplot as plt
# Out:
# C:\Users\jiyun\anaconda3\lib\site-packages\torchaudio\extension\extension.py:14: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')
# C:\Users\jiyun\anaconda3\lib\site-packages\torchaudio\backend\utils.py:63: UserWarning: The interface of "soundfile" backend is planned to change in 0.8.0 to match that of "sox_io" backend and the current interface will be removed in 0.9.0. To use the new interface, do `torchaudio.USE_SOUNDFILE_LEGACY_INTERFACE = False` before setting the backend to "soundfile". Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   warnings.warn(

# %%
dir_path = r"C:\Users\jiyun\Desktop\Jiyu\2020-2021\ESC499 - Thesis\WaveNet\magnatagatune\data\24_preludes_for_solo_piano"
files = glob.glob(os.path.join(dir_path, '*.mp3'))

# %%
len(files)
# Out:
# 50

# %%
chunk_size_s = 3

# %%
files[0]
# Out:
# 'C:\\Users\\jiyun\\Desktop\\Jiyu\\2020-2021\\ESC499 - Thesis\\WaveNet\\magnatagatune\\data\\24_preludes_for_solo_piano\\jan_hanford-24_preludes_for_solo_piano-01-prelude_no__1_in_f_minor-30-59.mp3'

# %%
filename = files[0]
print(filename)
waveform, sr = librosa.load(filename)
specgram = torchaudio.transforms.MelSpectrogram(n_mels=80, n_fft=256)(torch.Tensor(waveform).reshape(1,-1))
plt.figure(figsize=(80,10))
plt.imshow(specgram.log2()[0,:,:].detach().numpy())
plt.show()
# Out:
# C:\Users\jiyun\Desktop\Jiyu\2020-2021\ESC499 - Thesis\WaveNet\magnatagatune\data\24_preludes_for_solo_piano\jan_hanford-24_preludes_for_solo_piano-01-prelude_no__1_in_f_minor-30-59.mp3

# %%
# take a chunk to see better
chunk_size_s = 3
overlap = 0
chunk_size = int(chunk_size_s * sr)

def chunk_waveform(waveform, chunk_size, overlap):
    idx = 0
    # overlap_chunk = 0
    overlap_chunk = int(overlap * chunk_size)
    while idx + chunk_size - overlap_chunk <= len(waveform):
        yield waveform[idx:idx + chunk_size - overlap_chunk]
        idx += chunk_size - overlap_chunk

chunks = torch.FloatTensor(list(chunk_waveform(waveform, chunk_size, overlap)))
chunk = chunks[0]

specgram = torchaudio.transforms.MelSpectrogram(n_mels=80, n_fft=256)(chunk.reshape(1,-1))
plt.figure(figsize=(20,10))
plt.imshow(specgram.log2()[0,:,:].detach().numpy())
plt.show()

# %% [markdown]
# ***

# %%
filename = r"C:\Users\jiyun\Desktop\Jiyu\2020-2021\ESC499 - Thesis\WaveNet\magnatagatune\data\24_preludes_for_solo_piano\jan_hanford-24_preludes_for_solo_piano-19-prelude_no__19_in_g_minor-30-59.mp3"
print(filename)
waveform, sr = librosa.load(filename)
# Out:
# C:\Users\jiyun\Desktop\Jiyu\2020-2021\ESC499 - Thesis\WaveNet\magnatagatune\data\24_preludes_for_solo_piano\jan_hanford-24_preludes_for_solo_piano-19-prelude_no__19_in_g_minor-30-59.mp3

# %%
torch.Tensor(waveform)
# Out:
# tensor([0., 0., 0.,  ..., 0., 0., 0.])

# %%
specgram = torchaudio.transforms.MelSpectrogram(n_mels=80, n_fft=256)(torch.Tensor(waveform).reshape(1,-1))

# %%
plt.figure(figsize=(80,10))
plt.imshow(specgram.log2()[0,:,:].detach().numpy())
plt.show()

# %%
chunk_size_s = 5
overlap = 0
chunk_size = int(chunk_size_s * sr)

chunks = torch.FloatTensor(list(chunk_waveform(waveform, chunk_size, overlap)))
chunk = chunks[0]

specgram = torchaudio.transforms.MelSpectrogram(n_mels=80, n_fft=256)(chunk.reshape(1,-1))
plt.figure(figsize=(20,10))
plt.imshow(specgram.log2()[0,:,:].detach().numpy())
# plt.show()
plt.savefig(f"piano_{chunk_size_s}s.png")

# %%
500/256 * 2
# Out:
# 3.90625

# %%
chunk_size
# Out:
# 66150

# %%
400/(256//2) / sr
# Out:
# 0.0001417233560090703

# %%
3/516
# Out:
# 0.005813953488372093

# %% [markdown]
# ***

# %%
specgram = torchaudio.transforms.MelSpectrogram(n_mels=80, n_fft=256)(torch.Tensor(waveform).reshape(1,-1))
plt.figure(figsize=(80,10))
plt.imshow(specgram.log2()[0,:,:].detach().numpy())
# plt.show()
plt.savefig("twinkle_full_spec.png")

# %%
filename = r"C:\Users\jiyun\Desktop\Jiyu\2020-2021\ESC499 - Thesis\WaveNet\magnatagatune\data\twinkle\Easy Piano Tutorial Twinkle Twinkle Little Star-[AudioTrimmer.com].mp3"
waveform, sr = librosa.load(filename)
chunk_size_s = 5
overlap = 0
chunk_size = int(chunk_size_s * sr)

def chunk_waveform(waveform, chunk_size, overlap):
    idx = 0
    # overlap_chunk = 0
    overlap_chunk = int(overlap * chunk_size)
    while idx + chunk_size - overlap_chunk <= len(waveform):
        yield waveform[idx:idx + chunk_size - overlap_chunk]
        idx += chunk_size - overlap_chunk

chunks = torch.FloatTensor(list(chunk_waveform(waveform, chunk_size, overlap)))
chunk = chunks[0]

specgram = torchaudio.transforms.MelSpectrogram(n_mels=80, n_fft=256)(chunk.reshape(1,-1))
plt.figure(figsize=(20,10))
plt.imshow(specgram.log2()[0,:,:].detach().numpy())
# plt.show()
plt.savefig(f"twinkle_{chunk_size_s}s_spec.png")
# Out:
# C:\Users\jiyun\anaconda3\lib\site-packages\librosa\core\audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
len(chunk)/sr
# Out:
# 5.0

# %%
specgram.shape
# Out:
# torch.Size([1, 80, 862])

# %%
100 * (3/specgram.shape[-1])
# Out:
# 0.34802784222737815
